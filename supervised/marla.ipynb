# %% [markdown]
# # FIRST SUPERVISED MODEL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression as lr
from sklearn.metrics import mean_absolute_error ,mean_squared_error , r2_score

# %% [markdown]
# creating a house prediction system on the basis of marla an its price

# %%
x=np.array([
    [1],[2],[3]
])
y=np.array([
    [100000],[200000],[300000]
])

# %%
model=lr()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
m4=np.array([
    [5],[6],[7.6],[12]
])
price=model.predict(m4)
price
# Out:
# array([[ 500000.],
#        [ 600000.],
#        [ 760000.],
#        [1200000.]])

# %%
plt.plot(x, model.predict(x), color='red', label='Regression Line')

# %%
plt.scatter(m4, price, color='green', label='Predicted Points')

# %%
y_pred = model.predict(x)
print("MSE:", mean_squared_error(y, y_pred))
print("R² Score:", r2_score(y, y_pred))
# Out:
# MSE: 7.058607893785836e-23
# R² Score: 1.0
